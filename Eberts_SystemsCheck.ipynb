# %% [markdown]
# # Systems Check

# %% [markdown]
# ### This introductory assignment is to verify my environment is properly configured and that I can identify and submit the correct file types!

# %% [markdown]
# ###### From this class I hope to gain more experience coding and learning about how to make data more interesting

# %% [markdown]
# **So far I have coding experience in:**

# %% [markdown]
# - HTML

# %% [markdown]
# - CSS

# %% [markdown]
# - JavaScript

# %% [markdown]
# ![Excited Dog](https://static.boredpanda.com/blog/wp-content/uploads/2014/03/cute-smiling-animals-2.jpg)

# %% [markdown]
# *Me being excited for this semester*
